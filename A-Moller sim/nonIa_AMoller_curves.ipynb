# %%
import os
os.chdir("..")

# %%
from utils import *

# %%
n = 41  # 1 to 42
file = f"A-Moller sim/nonIa/DES_NONIa-{n:04d}_PHOT.FITS"
head = f"A-Moller sim/nonIa/DES_NONIa-{n:04d}_HEAD.FITS"

curves = reader(file, fits_header=True, band='FLT')
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    1 / number of data axes
# NAXIS1  =                    0 / length of data axis 1
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HIERARCH CODE_IVERSION =     7 / Internal SNFTSIO code version
# HIERARCH SNANA_PATH = '/project/rkessler/SN/SNANA/SNANA_CURRENT' / SNANA code di
# HIERARCH SNANA_VERSION = 'v10_60d ' / SNANA version
# SURVEY  = 'DES     '           / Survey
# HIERARCH SUBSURVEY_FLAG =    1 / SUBSURVEY_FLAG
# FILTERS = 'griz    '           / List of Filters
# VERSION = 'TMP_amol_AMDES_DL-0041_47257' / Photometry Version
# PHOTFILE= 'DES_NONIa-0041_PHOT.FITS' / Photometry FITS file
# ...

# %%
curves
# Out:
#            obs        MJD    FLT            FIELD  PHOTFLAG  PHOTPROB
# 0            0  56591.077  b'g '  b'X1          '         0       0.0  \
# 1            0  56591.079  b'r '  b'X1          '         0       0.0
# 2            0  56591.081  b'i '  b'X1          '         0       0.0
# 3            0  56591.084  b'z '  b'X1          '         0       0.0
# 4            0  56595.087  b'i '  b'X1          '         0       0.0
# ...        ...        ...    ...              ...       ...       ...
# 1506327  25604  57408.092  b'r '  b'C3          '         0       0.0
# 1506328  25604  57425.087  b'i '  b'C3          '         0       0.0
# 1506329  25604  57425.110  b'g '  b'C3          '         0       0.0
# 1506330  25604  57426.072  b'z '  b'C3          '         0       0.0
# 1506331  25604  57426.118  b'r '  b'C3          '         0       0.0
#
#             FLUXCAL  FLUXCALERR  PSF_SIG1  PSF_SIG2  PSF_RATIO     SKY_SIG
# ...

# %%
n = len(curves['obs'].value_counts())
print("# objects:", n)

np.random.seed(42)

for i in np.random.randint(1, n, 20):
    plotter(curves, i, info=head)
# Out:
# # objects: 25605
