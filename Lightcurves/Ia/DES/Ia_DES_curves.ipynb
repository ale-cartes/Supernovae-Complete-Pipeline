# %%
import os
import matplotlib as mpl

if 'path' not in globals():
    path = os.getcwd()

os.chdir(f'{path}\..\..\..')
print(os.getcwd())

from utils import *
# Out:
# c:\Users\aleja\Desktop\Supernovae Pipeline\Supernovae-Complete-Pipeline

# %%
path_curves = "Lightcurves"
file = path_curves + "/curves/Ia/DES/DES_Ia_PHOT.FITS"
head_file = path_curves + "/curves/Ia/DES/DES_Ia_HEAD.FITS"

curves = reader(file, fits_header=True)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    1 / number of data axes
# NAXIS1  =                    0 / length of data axis 1
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HIERARCH CODE_IVERSION =    21 / Internal SNFTSIO code version
# HIERARCH SNANA_PATH = '/home/acartes/Documents/SNANA' / SNANA code directory
# HIERARCH SNANA_VERSION = 'v11_04m ' / SNANA version
# SURVEY  = 'DES     '           / Survey
# HIERARCH SUBSURVEY_FLAG =    0 / SUBSURVEY_FLAG
# HIERARCH MWEBV_APPLYFLAG =   0 / 1 -> Apply MWEBV cor to FLUXCAL
# HIERARCH PHOTFLAG_DETECT = 4096 / PHOTFLAG mask for detection
# FILTERS = 'griz    '           / List of Filters
# ...

# %%
curves.head()
# Out:
#    obs        MJD BAND  CCDNUM            FIELD  PHOTFLAG  PHOTPROB  \
# 0    0  57303.133   i       -9  b'X2          '         0      -9.0
# 1    0  57303.136   z       -9  b'X2          '         0      -9.0
# 2    0  57304.192   g       -9  b'X2          '         0      -9.0
# 3    0  57304.194   r       -9  b'X2          '         0      -9.0
# 4    0  57304.196   i       -9  b'X2          '         0      -9.0
#
#      FLUXCAL  FLUXCALERR  PSF_SIG1  ...    SKY_SIG  SKY_SIG_T  RDNOISE  \
# 0   2.640354   35.851097  4.419657  ...  23.040001   3.521801      0.0
# 1  12.275355   58.633430  3.853437  ...  43.939999   4.023441      0.0
# 2  -2.185612    5.837152  2.909738  ...   7.780000   2.761245      0.0
# 3  10.177992   11.583814  2.673814  ...  11.840000   2.976186      0.0
# 4  -8.342690    7.600185  2.469346  ...  19.459999   8.448212      0.0
#
#       ZEROPT  ZEROPT_ERR  GAIN  XPIX  YPIX  SIM_FLUXCAL_HOSTERR  SIM_MAGOBS
# ...

# %%
n = len(curves['obs'].value_counts())
print("# objects:", n)

np.random.seed(42)

# for obs in np.random.randint(0, n, 5):
#     fig, ax = plotter(curves, obs, head_file=head_file)

mpl.rcParams['axes.titlesize'] = 18
mpl.rcParams['axes.labelsize'] = 18
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 14

fig, ax = plotter(curves, 2, head_file=head_file, days=True)
# Out:
# # objects: 100000

# %%
fig.savefig("Ia.svg", bbox_inches="tight", transparent=False, pad_inches=0)
