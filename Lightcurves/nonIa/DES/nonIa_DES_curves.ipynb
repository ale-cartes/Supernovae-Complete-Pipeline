# %%
import os
import matplotlib as mpl

if 'path' not in globals():
    path = os.getcwd()

os.chdir(f'{path}\..\..\..')
print(os.getcwd())

from utils import *
# Out:
# c:\Users\aleja\Desktop\Supernovae Pipeline\Supernovae-Complete-Pipeline

# %%
path_curves = "Lightcurves"
file = path_curves + "/curves/nonIa/DES/DES_nonIa_PHOT.FITS"
head_file = path_curves + "/curves/nonIa/DES/DES_nonIa_HEAD.FITS"

curves_class = SN_data(phot_file=file, head_file=head_file)
curves_class.reader(fits_header=True)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    1 / number of data axes
# NAXIS1  =                    0 / length of data axis 1
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HIERARCH CODE_IVERSION =    21 / Internal SNFTSIO code version
# HIERARCH SNANA_PATH = '/home/acartes/Documents/SNANA' / SNANA code directory
# HIERARCH SNANA_VERSION = 'v11_04m ' / SNANA version
# SURVEY  = 'DES     '           / Survey
# HIERARCH SUBSURVEY_FLAG =    0 / SUBSURVEY_FLAG
# HIERARCH MWEBV_APPLYFLAG =   0 / 1 -> Apply MWEBV cor to FLUXCAL
# HIERARCH PHOTFLAG_DETECT = 4096 / PHOTFLAG mask for detection
# FILTERS = 'griz    '           / List of Filters
# ...

# %%
curves_class.lc_df.head()
# Out:
#            MJD BAND  CCDNUM            FIELD  PHOTFLAG  PHOTPROB   FLUXCAL  \
# obs
# 0    56920.196    g      -9  b'C3          '         0      -9.0 -2.433779
# 0    56920.205    r      -9  b'C3          '         0      -9.0 -0.079228
# 0    56920.221    i      -9  b'C3          '         0      -9.0 -2.320011
# 0    56920.245    z      -9  b'C3          '         0      -9.0 -0.266453
# 0    56925.188    g      -9  b'C3          '         0      -9.0 -2.978069
#
#      FLUXCALERR  PSF_SIG1  PSF_SIG2  ...    SKY_SIG  SKY_SIG_T  RDNOISE  \
# obs                                  ...
# 0      1.918738  2.422161       0.0  ...  13.260000   6.797417      0.0
# 0      1.420173  1.934583       0.0  ...  31.309999  12.573341      0.0
# 0      1.599790  1.808756       0.0  ...  53.250000  22.186205      0.0
# 0      2.044643  1.887398       0.0  ...  97.470001  46.355465      0.0
# 0      1.859970  2.390704       0.0  ...  12.960000   6.797417      0.0
#
# ...

# %%
n = len(curves_class.lc_df.index.value_counts())
print("# objects:", n)

np.random.seed(42)

# for obs in np.random.randint(0, n, 5):
#     fig, ax = curves_class.plotter(obs=obs, days=True)

mpl.rcParams['axes.titlesize'] = 18
mpl.rcParams['axes.labelsize'] = 18
mpl.rcParams['xtick.labelsize'] = 14
mpl.rcParams['ytick.labelsize'] = 14
mpl.rcParams['legend.fontsize'] = 14

fig, ax = curves_class.plotter(obs=48288, days=True)
# Out:
# # objects: 100000

# %%
# fig.savefig('noIa.svg', bbox_inches="tight", pad_inches=0, transparent=True)

# %%
curves_class.obs_summary()
curves_class.obs_info['SNTYPE'].hist()
# Out:
# <Axes: >
