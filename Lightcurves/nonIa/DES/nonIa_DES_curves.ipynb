# %%
import os

if 'path' not in globals():
    path = os.getcwd()

os.chdir(f'{path}\..\..\..')
print(os.getcwd())

from utils import *
# Out:
# c:\Users\aleja\Desktop\Supernovae Pipeline\Supernovae-Complete-Pipeline

# %%
path = ".."

file = path + "/curves/nonIa/DES/DES_nonIa_PHOT.FITS"

curves = reader(file, fits_header=True)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    1 / number of data axes
# NAXIS1  =                    0 / length of data axis 1
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HIERARCH CODE_IVERSION =    21 / Internal SNFTSIO code version
# HIERARCH SNANA_PATH = '/home/acartes/Documents/SNANA' / SNANA code directory
# HIERARCH SNANA_VERSION = 'v11_04m ' / SNANA version
# SURVEY  = 'DES     '           / Survey
# HIERARCH SUBSURVEY_FLAG =    0 / SUBSURVEY_FLAG
# HIERARCH MWEBV_APPLYFLAG =   0 / 1 -> Apply MWEBV cor to FLUXCAL
# HIERARCH PHOTFLAG_DETECT = 4096 / PHOTFLAG mask for detection
# FILTERS = 'griz    '           / List of Filters
# VERSION = 'DES_nonIa'          / Photometry Version
# PHOTFILE= 'DES_nonIa_PHOT.FITS' / Photometry FITS file
# DATATYPE= 'SIM_SNANA'          / SNANA Simulation
# LONGSTRN= 'OGIP 1.0'           / The HEASARC Long String Convention may be used.
# COMMENT   This FITS file may contain long string keyword values that are
# COMMENT   continued over multiple keywords.  The HEASARC convention uses the &
# COMMENT   character at the end of each substring which is then continued
# COMMENT   on the next keyword which has the name CONTINUE.
# HIERARCH SIMLIB_FILE= '/home/acartes/Documents/SNDATA_ROOT/simlib/DES/DES-SN5YR'
# CONTINUE  'FFIMG.SIMLIB'       / SIMLIB Cadence/conditions File
# HIERARCH KCOR_FILE= '/home/acartes/Documents/SNDATA_ROOT/kcor/DES/DES-SN3YR/kco'
# CONTINUE  '.fits   '           / KCOR/calibration file
# HIERARCH SIMLIB_MSKOPT =     0 / SIMLIB options mask
# HIERARCH HOSTLIB_FILE = 'NONE    ' / name of HOSTLIB file
# HIERARCH SIM_MODEL_INDEX =  10 / SIM MODEL index
# HIERARCH SIMOPT_MWCOLORLAW = 94 / option for MW color law
# SIM_MWRV=                  3.1 / RV for Galactic extinction
# HIERARCH SIMOPT_MWEBV =      1 / option for MWEBV_SFD
# HIERARCH SIMOPT_FLUXERR =    0 / option for fudgeing fluxErrors
# HIERARCH SIM_NSUBSAMPLE_MARK = 0 / Number of marked subSamples
# HIERARCH SIM_VARNAME_SNRMON = '        ' / PHOT varName for SNR(MAGMONITOR)
# HIERARCH SIM_SL_FLAG =       0 / Strong lens flag
# HIERARCH SIM_BIASCOR_MASK =  0 / biasCor mask

# %%
file_summary = "Lightcurves/nonIa/DES/DES_nonIa.DUMP"

table_summary = summary(file_summary)

# %%
curves
# Out:
#           obs        MJD   BAND  CCDNUM            FIELD  PHOTFLAG  PHOTPROB  \
# 0           1  56920.196  b'g '      -9  b'C3          '         0      -9.0
# 1           1  56920.205  b'r '      -9  b'C3          '         0      -9.0
# 2           1  56920.221  b'i '      -9  b'C3          '         0      -9.0
# 3           1  56920.245  b'z '      -9  b'C3          '         0      -9.0
# 4           1  56925.188  b'g '      -9  b'C3          '         0      -9.0
# ...       ...        ...    ...     ...              ...       ...       ...
# 702073  10000  58076.132  b'z '      -9  b'X1          '         0      -9.0
# 702074  10000  58082.062  b'g '      -9  b'X1          '         0      -9.0
# 702075  10000  58082.064  b'r '      -9  b'X1          '         0      -9.0
# 702076  10000  58082.066  b'i '      -9  b'X1          '         0      -9.0
# 702077  10000  58082.071  b'z '      -9  b'X1          '         0      -9.0
#
#           FLUXCAL  FLUXCALERR  PSF_SIG1  ...     SKY_SIG  SKY_SIG_T  RDNOISE  \
# 0       -2.433779    1.918738  2.422161  ...   13.260000   6.797417      0.0
# 1       -0.079228    1.420173  1.934583  ...   31.309999  12.573341      0.0
# 2       -2.320011    1.599790  1.808756  ...   53.250000  22.186205      0.0
# 3       -0.266453    2.044643  1.887398  ...   97.470001  46.355465      0.0
# 4       -2.978069    1.859970  2.390704  ...   12.960000   6.797417      0.0
# ...           ...         ...       ...  ...         ...        ...      ...
# 702073  17.407907    9.115328  2.044681  ...  174.050003  57.595924      0.0
# 702074   4.923561    5.813327  2.705270  ...   43.410000  10.612934      0.0
# 702075  -6.445468    8.836266  2.626629  ...   52.029999  50.711052      0.0
# 702076  10.244852    9.723999  2.516531  ...   94.949997  55.444656      0.0
# 702077  12.014324   10.851946  2.359247  ...  201.320007  64.326775      0.0
#
#            ZEROPT  ZEROPT_ERR  GAIN  XPIX  YPIX  SIM_FLUXCAL_HOSTERR  \
# 0       32.060001       0.001  3.65  -9.0  -9.0                  0.0
# 1       33.029999       0.000  3.91  -9.0  -9.0                  0.0
# 2       33.410000       0.000  3.93  -9.0  -9.0                  0.0
# 3       33.869999       0.000  3.93  -9.0  -9.0                  0.0
# 4       32.060001       0.001  3.63  -9.0  -9.0                  0.0
# ...           ...         ...   ...   ...   ...                  ...
# 702073  32.910000       0.001  1.03  -9.0  -9.0                  0.0
# 702074  32.169998       0.002  1.04  -9.0  -9.0                  0.0
# 702075  32.209999       0.002  1.03  -9.0  -9.0                  0.0
# 702076  32.509998       0.001  1.01  -9.0  -9.0                  0.0
# 702077  33.029999       0.002  1.03  -9.0  -9.0                  0.0
#
#         SIM_MAGOBS
# 0        30.996391
# 1        29.598324
# 2        30.352036
# 3        31.015488
# 4        27.910400
# ...            ...
# 702073   24.879969
# 702074   30.420189
# 702075   26.363579
# 702076   25.331537
# 702077   24.905251
#
# [702078 rows x 22 columns]

# %%
print("# objects:", len(curves['obs'].value_counts()))

np.random.seed(42)

for i in np.random.randint(1, 100, 20):
    summary = table_summary[table_summary['CID']==i]
    plotter(curves, i, summary=summary)
# Out:
# # objects: 10000

# %%
table_summary['SNTYPE'].hist()
# Out:
# <AxesSubplot:>
