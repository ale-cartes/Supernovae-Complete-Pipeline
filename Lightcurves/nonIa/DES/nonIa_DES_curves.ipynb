# %%
import os

if 'path' not in globals():
    path = os.getcwd()

os.chdir(f'{path}\..\..\..')
print(os.getcwd())

from utils import *
# Out:
# c:\Users\aleja\Desktop\Supernovae Pipeline\Supernovae-Complete-Pipeline

# %%
path_curves = "Lightcurves"
file = path_curves + "/curves/nonIa/DES/DES_nonIa_PHOT.FITS"
head_file = path_curves + "/curves/nonIa/DES/DES_nonIa_HEAD.FITS"

curves = reader(file, fits_header=True)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    1 / number of data axes
# NAXIS1  =                    0 / length of data axis 1
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HIERARCH CODE_IVERSION =    21 / Internal SNFTSIO code version
# HIERARCH SNANA_PATH = '/home/acartes/Documents/SNANA' / SNANA code directory
# HIERARCH SNANA_VERSION = 'v11_04m ' / SNANA version
# SURVEY  = 'DES     '           / Survey
# HIERARCH SUBSURVEY_FLAG =    0 / SUBSURVEY_FLAG
# HIERARCH MWEBV_APPLYFLAG =   0 / 1 -> Apply MWEBV cor to FLUXCAL
# HIERARCH PHOTFLAG_DETECT = 4096 / PHOTFLAG mask for detection
# FILTERS = 'griz    '           / List of Filters
# ...

# %%
curves.head()
# Out:
#    obs        MJD BAND  CCDNUM            FIELD  PHOTFLAG  PHOTPROB   FLUXCAL
# 0    0  56920.196   g       -9  b'C3          '         0      -9.0 -2.433779  \
# 1    0  56920.205   r       -9  b'C3          '         0      -9.0 -0.079228
# 2    0  56920.221   i       -9  b'C3          '         0      -9.0 -2.320011
# 3    0  56920.245   z       -9  b'C3          '         0      -9.0 -0.266453
# 4    0  56925.188   g       -9  b'C3          '         0      -9.0 -2.978069
#
#    FLUXCALERR  PSF_SIG1  ...    SKY_SIG  SKY_SIG_T  RDNOISE     ZEROPT
# 0    1.918738  2.422161  ...  13.260000   6.797417      0.0  32.060001  \
# 1    1.420173  1.934583  ...  31.309999  12.573341      0.0  33.029999
# 2    1.599790  1.808756  ...  53.250000  22.186205      0.0  33.410000
# 3    2.044643  1.887398  ...  97.470001  46.355465      0.0  33.869999
# 4    1.859970  2.390704  ...  12.960000   6.797417      0.0  32.060001
#
#    ZEROPT_ERR  GAIN  XPIX  YPIX  SIM_FLUXCAL_HOSTERR  SIM_MAGOBS
# ...

# %%
n = len(curves['obs'].value_counts())
print("# objects:", n)

np.random.seed(42)

for obs in np.random.randint(1, n, 5):
    fig, ax = plotter(curves, obs, head_file="Lightcurves\curves/nonIa\DES\DES_nonIa_HEAD.FITS")
# Out:
# # objects: 100000

# %%
# fig.savefig('noIa.svg', bbox_inches="tight", pad_inches=0, transparent=True)

# %%
summary_nonIa = summary(head_file)
summary_nonIa['SNTYPE'].hist()
# Out:
# <AxesSubplot:>
