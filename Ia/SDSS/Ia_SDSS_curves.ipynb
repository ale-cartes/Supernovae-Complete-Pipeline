# %%
cd ~/Desktop/Supernovae_Complete_Pipeline
# Out:
# /home/acartes/Desktop/Supernovae_Complete_Pipeline

# %%
import fits_plotter

# %%
file = "SDSS_Ia_PHOT.FITS"

curves = reader(file, fits_header=True)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    1 / number of data axes
# NAXIS1  =                    0 / length of data axis 1
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HIERARCH CODE_IVERSION =    21 / Internal SNFTSIO code version
# HIERARCH SNANA_PATH = '/home/acartes/Documentos/SNANA' / SNANA code directory
# HIERARCH SNANA_VERSION = 'v11_04m ' / SNANA version
# SURVEY  = 'SDSS    '           / Survey
# HIERARCH SUBSURVEY_FLAG =    0 / SUBSURVEY_FLAG
# HIERARCH MWEBV_APPLYFLAG =   0 / 1 -> Apply MWEBV cor to FLUXCAL
# HIERARCH PHOTFLAG_DETECT =   0 / PHOTFLAG mask for detection
# FILTERS = 'ugriz   '           / List of Filters
# VERSION = 'Ia_SDSS '           / Photometry Version
# PHOTFILE= 'Ia_SDSS_PHOT.FITS'  / Photometry FITS file
# DATATYPE= 'SIM_SNANA'          / SNANA Simulation
# LONGSTRN= 'OGIP 1.0'           / The HEASARC Long String Convention may be used.
# COMMENT   This FITS file may contain long string keyword values that are
# COMMENT   continued over multiple keywords.  The HEASARC convention uses the &
# COMMENT   character at the end of each substring which is then continued
# COMMENT   on the next keyword which has the name CONTINUE.
# HIERARCH SIMLIB_FILE= '/home/acartes/Documentos/SNDATA_ROOT/simlib/SDSS/SDSS200'
# CONTINUE  '.SIMLIB '           / SIMLIB Cadence/conditions File
# HIERARCH KCOR_FILE= '/home/acartes/Documentos/SNDATA_ROOT/kcor/SDSS/SNCOSM09+fi'
# CONTINUE  't/kcor_SDSS_Bessell90_BD17.fits' / KCOR/calibration file
# HIERARCH SIMLIB_MSKOPT =     0 / SIMLIB options mask
# HIERARCH HOSTLIB_FILE = 'NONE    ' / name of HOSTLIB file
# HIERARCH SIM_MODEL_INDEX =   6 / SIM MODEL index
# HIERARCH SIMOPT_MWCOLORLAW = 94 / option for MW color law
# SIM_MWRV=                  3.1 / RV for Galactic extinction
# HIERARCH SIMOPT_MWEBV =      1 / option for MWEBV_SFD
# HIERARCH SIMOPT_FLUXERR =    0 / option for fudgeing fluxErrors
# HIERARCH SIM_NSUBSAMPLE_MARK = 0 / Number of marked subSamples
# HIERARCH SIM_VARNAME_SNRMON = '        ' / PHOT varName for SNR(MAGMONITOR)
# HIERARCH SIM_SL_FLAG =       0 / Strong lens flag
# HIERARCH SIM_BIASCOR_MASK =  0 / biasCor mask

# %%
curves
# Out:
#       obs        MJD   BAND  CCDNUM            FIELD  PHOTFLAG  PHOTPROB  \
# 0       1  53671.383  b'u '      -9  b'82S         '         0      -9.0
# 1       1  53671.383  b'g '      -9  b'82S         '         0      -9.0
# 2       1  53671.383  b'r '      -9  b'82S         '         0      -9.0
# 3       1  53671.383  b'i '      -9  b'82S         '         0      -9.0
# 4       1  53674.285  b'u '      -9  b'82S         '         0      -9.0
# ...   ...        ...    ...     ...              ...       ...       ...
# 8770  200  53699.273  b'i '      -9  b'82N         '         0      -9.0
# 8771  200  53704.242  b'u '      -9  b'82N         '         0      -9.0
# 8772  200  53704.242  b'g '      -9  b'82N         '         0      -9.0
# 8773  200  53704.242  b'r '      -9  b'82N         '         0      -9.0
# 8774  200  53704.242  b'i '      -9  b'82N         '         0      -9.0
#
#            FLUXCAL  FLUXCALERR  PSF_SIG1  ...  SKY_SIG  SKY_SIG_T  RDNOISE  \
# 0     2.511886e-29   80.142189      1.65  ...     5.00        0.0     5.66
# 1     2.511885e-29   19.184782      1.48  ...     4.96        0.0     4.63
# 2     8.413516e-02   24.458942      1.02  ...     6.61        0.0     4.60
# 3     2.511885e-29   39.680294      1.07  ...     7.25        0.0    15.76
# 4     2.511885e-29   61.132450      1.98  ...     4.75        0.0     5.66
# ...            ...         ...       ...  ...      ...        ...      ...
# 8770  4.003006e+02   33.557613      0.99  ...     7.65        0.0    10.45
# 8771  1.886062e+01   65.460098      2.39  ...     4.22        0.0     4.69
# 8772  1.915609e+02   18.679176      1.88  ...     4.32        0.0     4.42
# 8773  3.490462e+02   30.595255      1.78  ...     5.89        0.0     5.43
# 8774  3.087680e+02   49.148567      1.80  ...     7.56        0.0    10.45
#
#          ZEROPT  ZEROPT_ERR  GAIN  XPIX  YPIX  SIM_FLUXCAL_HOSTERR  SIM_MAGOBS
# 0     27.010000         0.0  1.60  -9.0  -9.0                  0.0   99.000000
# 1     28.280001         0.0  3.86  -9.0  -9.0                  0.0   99.000000
# 2     28.070000         0.0  4.60  -9.0  -9.0                  0.0   30.187557
# 3     27.700001         0.0  6.57  -9.0  -9.0                  0.0   99.000000
# 4     27.360001         0.0  1.60  -9.0  -9.0                  0.0   99.000000
# ...         ...         ...   ...   ...   ...                  ...         ...
# 8770  27.940001         0.0  4.86  -9.0  -9.0                  0.0   20.994034
# 8771  27.370001         0.0  1.59  -9.0  -9.0                  0.0   24.311110
# 8772  28.500000         0.0  3.85  -9.0  -9.0                  0.0   21.794233
# 8773  28.219999         0.0  4.72  -9.0  -9.0                  0.0   21.142794
# 8774  27.959999         0.0  4.86  -9.0  -9.0                  0.0   21.275921
#
# [8775 rows x 22 columns]

# %%
print("# objects:", len(curves['obs'].value_counts()))

np.random.seed(45)

for i in np.random.randint(1, 200, 10):
    plotter(curves, i)
# Out:
# # objects: 200
