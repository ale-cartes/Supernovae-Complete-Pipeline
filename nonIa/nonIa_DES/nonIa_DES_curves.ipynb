# %%
run "../../fits_plotter.py"

# %%
# !pwd
# Out:
# /home/acartes/Escritorio/Supernovae-Complete-Pipeline/nonIa/nonIa_DES

# %%
file = "nonIa_DES_PHOT.FITS"

curves = reader(file, fits_header=True)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    1 / number of data axes
# NAXIS1  =                    0 / length of data axis 1
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HIERARCH CODE_IVERSION =    21 / Internal SNFTSIO code version
# HIERARCH SNANA_PATH = '/home/acartes/Documentos/SNANA' / SNANA code directory
# HIERARCH SNANA_VERSION = 'v11_04m ' / SNANA version
# SURVEY  = 'DES     '           / Survey
# HIERARCH SUBSURVEY_FLAG =    0 / SUBSURVEY_FLAG
# HIERARCH MWEBV_APPLYFLAG =   0 / 1 -> Apply MWEBV cor to FLUXCAL
# HIERARCH PHOTFLAG_DETECT = 4096 / PHOTFLAG mask for detection
# FILTERS = 'griz    '           / List of Filters
# VERSION = 'nonIa_DES'          / Photometry Version
# PHOTFILE= 'nonIa_DES_PHOT.FITS' / Photometry FITS file
# DATATYPE= 'SIM_SNANA'          / SNANA Simulation
# LONGSTRN= 'OGIP 1.0'           / The HEASARC Long String Convention may be used.
# COMMENT   This FITS file may contain long string keyword values that are
# COMMENT   continued over multiple keywords.  The HEASARC convention uses the &
# COMMENT   character at the end of each substring which is then continued
# COMMENT   on the next keyword which has the name CONTINUE.
# HIERARCH SIMLIB_FILE= '/home/acartes/Documentos/SNDATA_ROOT/simlib/DES/DES_10fi'
# CONTINUE  'z_B12.SIMLIB'       / SIMLIB Cadence/conditions File
# HIERARCH KCOR_FILE= '/home/acartes/Documentos/SNDATA_ROOT/kcor/DES/DES-SN3YR/kc'
# CONTINUE  'm.fits  '           / KCOR/calibration file
# HIERARCH SIMLIB_MSKOPT =     0 / SIMLIB options mask
# HIERARCH HOSTLIB_FILE = 'NONE    ' / name of HOSTLIB file
# HIERARCH SIM_MODEL_INDEX =  10 / SIM MODEL index
# HIERARCH SIMOPT_MWCOLORLAW = 94 / option for MW color law
# SIM_MWRV=                  3.1 / RV for Galactic extinction
# HIERARCH SIMOPT_MWEBV =      1 / option for MWEBV_SFD
# HIERARCH SIMOPT_FLUXERR =    0 / option for fudgeing fluxErrors
# HIERARCH SIM_NSUBSAMPLE_MARK = 0 / Number of marked subSamples
# HIERARCH SIM_VARNAME_SNRMON = '        ' / PHOT varName for SNR(MAGMONITOR)
# HIERARCH SIM_SL_FLAG =       0 / Strong lens flag
# HIERARCH SIM_BIASCOR_MASK =  0 / biasCor mask

# %%
curves
# Out:
#      obs        MJD   BAND  CCDNUM            FIELD  PHOTFLAG  PHOTPROB  \
# 0      1  56277.180  b'z '      -9  b'shallow7    '         0      -9.0
# 1      1  56278.223  b'g '      -9  b'shallow7    '      4096      -9.0
# 2      1  56279.180  b'r '      -9  b'shallow7    '      4096      -9.0
# 3      1  56279.199  b'i '      -9  b'shallow7    '         0      -9.0
# 4      1  56288.152  b'z '      -9  b'shallow7    '      4096      -9.0
# ..   ...        ...    ...     ...              ...       ...       ...
# 972   20  56341.055  b'i '      -9  b'shallow7    '      4096      -9.0
# 973   20  56345.992  b'g '      -9  b'shallow7    '      4096      -9.0
# 974   20  56346.039  b'r '      -9  b'shallow7    '         0      -9.0
# 975   20  56348.023  b'z '      -9  b'shallow7    '      4096      -9.0
# 976   20  56351.004  b'i '      -9  b'shallow7    '      4096      -9.0
#
#         FLUXCAL  FLUXCALERR  PSF_SIG1  ...     SKY_SIG  SKY_SIG_T  RDNOISE  \
# 0      4.155930    5.377977      1.36  ...  214.210007        0.0     10.0
# 1      9.343095    2.382162      1.58  ...   36.380001        0.0     10.0
# 2     39.001358    7.007766      1.53  ...   27.600000        0.0     10.0
# 3      4.158342    7.721427      2.11  ...   76.190002        0.0     10.0
# 4    212.072357    9.919240      1.93  ...  274.510010        0.0     10.0
# ..          ...         ...       ...  ...         ...        ...      ...
# 972   96.795700   13.653014      2.58  ...  109.309998        0.0     10.0
# 973   24.879894    6.143916      1.90  ...   76.330002        0.0     10.0
# 974   67.859558    9.970518      1.94  ...   34.849998        0.0     10.0
# 975   65.432289    9.255661      1.76  ...  245.429993        0.0     10.0
# 976   87.093254    8.536574      2.21  ...   76.190002        0.0     10.0
#
#         ZEROPT  ZEROPT_ERR  GAIN  XPIX  YPIX  SIM_FLUXCAL_HOSTERR  SIM_MAGOBS
# 0    33.209999        0.02   1.0  -9.0  -9.0                  0.0   26.192982
# 1    32.380001        0.02   1.0  -9.0  -9.0                  0.0   24.669960
# 2    30.910000        0.02   1.0  -9.0  -9.0                  0.0   24.039454
# 3    32.180000        0.02   1.0  -9.0  -9.0                  0.0   24.477762
# 4    33.200001        0.02   1.0  -9.0  -9.0                  0.0   21.634199
# ..         ...         ...   ...   ...   ...                  ...         ...
# 972  32.169998        0.02   1.0  -9.0  -9.0                  0.0   22.655842
# 973  32.320000        0.02   1.0  -9.0  -9.0                  0.0   23.603878
# 974  31.010000        0.02   1.0  -9.0  -9.0                  0.0   22.977972
# 975  33.049999        0.02   1.0  -9.0  -9.0                  0.0   23.029268
# 976  32.130001        0.02   1.0  -9.0  -9.0                  0.0   22.742968
#
# [977 rows x 22 columns]

# %%
print("# objects:", len(curves['obs'].value_counts()))

np.random.seed(45)

for i in np.random.randint(1, 18, 10):
    plotter(curves, i)
# Out:
# # objects: 20

# %% [markdown]
# ### Problem:
#
# Which types there are? is not clear
