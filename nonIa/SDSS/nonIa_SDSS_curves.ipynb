# %%
cd ~/Desktop/Supernovae_Complete_Pipeline
# Out:
# /home/acartes/Desktop/Supernovae_Complete_Pipeline

# %%
from fits_plotter import *

# %%
file = "nonIa/SDSS/SDSS_nonIa_PHOT.FITS"

curves = reader(file, fits_header=True)
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    1 / number of data axes
# NAXIS1  =                    0 / length of data axis 1
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# HIERARCH CODE_IVERSION =    21 / Internal SNFTSIO code version
# HIERARCH SNANA_PATH = '/home/acartes/Documents/SNANA' / SNANA code directory
# HIERARCH SNANA_VERSION = 'v11_04m ' / SNANA version
# SURVEY  = 'SDSS    '           / Survey
# HIERARCH SUBSURVEY_FLAG =    0 / SUBSURVEY_FLAG
# HIERARCH MWEBV_APPLYFLAG =   0 / 1 -> Apply MWEBV cor to FLUXCAL
# HIERARCH PHOTFLAG_DETECT =   0 / PHOTFLAG mask for detection
# FILTERS = 'ugriz   '           / List of Filters
# VERSION = 'SDSS_nonIa'         / Photometry Version
# PHOTFILE= 'SDSS_nonIa_PHOT.FITS' / Photometry FITS file
# DATATYPE= 'SIM_SNANA'          / SNANA Simulation
# LONGSTRN= 'OGIP 1.0'           / The HEASARC Long String Convention may be used.
# COMMENT   This FITS file may contain long string keyword values that are
# COMMENT   continued over multiple keywords.  The HEASARC convention uses the &
# COMMENT   character at the end of each substring which is then continued
# COMMENT   on the next keyword which has the name CONTINUE.
# HIERARCH SIMLIB_FILE= '/home/acartes/Documents/SNDATA_ROOT/simlib/SDSS/SDSS_3ye'
# CONTINUE  'IB      '           / SIMLIB Cadence/conditions File
# HIERARCH KCOR_FILE= '/home/acartes/Documents/SNDATA_ROOT/kcor/SDSS/SNCOSM09+fit'
# CONTINUE  '/kcor_SDSS_Bessell90_BD17.fits' / KCOR/calibration file
# HIERARCH SIMLIB_MSKOPT =     0 / SIMLIB options mask
# HIERARCH HOSTLIB_FILE = 'NONE    ' / name of HOSTLIB file
# HIERARCH SIM_MODEL_INDEX =  10 / SIM MODEL index
# HIERARCH SIMOPT_MWCOLORLAW = 94 / option for MW color law
# SIM_MWRV=                  3.1 / RV for Galactic extinction
# HIERARCH SIMOPT_MWEBV =      1 / option for MWEBV_SFD
# HIERARCH SIMOPT_FLUXERR =    0 / option for fudgeing fluxErrors
# HIERARCH SIM_NSUBSAMPLE_MARK = 0 / Number of marked subSamples
# HIERARCH SIM_VARNAME_SNRMON = '        ' / PHOT varName for SNR(MAGMONITOR)
# HIERARCH SIM_SL_FLAG =       0 / Strong lens flag
# HIERARCH SIM_BIASCOR_MASK =  0 / biasCor mask

# %%
file_summary = "nonIa/SDSS/SDSS_nonIa.DUMP"

table_summary = summary(file_summary)

table_summary
# Out:
#     CID         Z    PEAKMJD  SALT2c  SALT2x1    SNRMAX  TRESTMIN  TRESTMAX  \
# 0     1  0.164969  54044.608      -9       -9  13.90540 -19.90290   17.7857
# 1     2  0.254879  54370.184      -9       -9   8.69911 -18.94840   50.3157
# 2     3  0.140692  53651.141      -9       -9  23.72450 -14.88620   45.5727
# 3     4  0.087762  54036.523      -9       -9  14.09250 -14.89600   29.1955
# 4     5  0.108151  53665.387      -9       -9  11.98770 -15.43630   35.9023
# ..  ...       ...        ...     ...      ...       ...       ...       ...
# 95   96  0.051287  54384.733      -9       -9  44.51730  -5.12256   37.5442
# 96   97  0.095060  53637.770      -9       -9  14.22880 -13.33800   59.6572
# 97   98  0.065394  54420.302      -9       -9  38.24340 -16.80820    3.7053
# 98   99  0.089262  53998.351      -9       -9  28.83970  -8.19714   61.5070
# 99  100  0.090425  54391.570      -9       -9  13.48380 -14.00300   28.0888
#
#     NON1A_INDEX  SNTYPE
# 0           201  II+IIP
# 1           201  II+IIP
# 2           201  II+IIP
# 3           204  II+IIP
# 4           204  II+IIP
# ..          ...     ...
# 95           22  Ic+Ibc
# 96           22  Ic+Ibc
# 97          101  Ic+Ibc
# 98          101  Ic+Ibc
# 99          102  Ic+Ibc
#
# [100 rows x 10 columns]

# %%
curves
# Out:
#       obs        MJD   BAND  CCDNUM            FIELD  PHOTFLAG  PHOTPROB  \
# 0       1  54021.422  b'u '      -9  b'82N         '         0      -9.0
# 1       1  54021.422  b'g '      -9  b'82N         '         0      -9.0
# 2       1  54021.422  b'r '      -9  b'82N         '         0      -9.0
# 3       1  54021.422  b'i '      -9  b'82N         '         0      -9.0
# 4       1  54021.422  b'z '      -9  b'82N         '         0      -9.0
# ...   ...        ...    ...     ...              ...       ...       ...
# 8707  100  54418.195  b'i '      -9  b'82S         '         0      -9.0
# 8708  100  54422.199  b'u '      -9  b'82S         '         0      -9.0
# 8709  100  54422.199  b'g '      -9  b'82S         '         0      -9.0
# 8710  100  54422.199  b'r '      -9  b'82S         '         0      -9.0
# 8711  100  54422.199  b'i '      -9  b'82S         '         0      -9.0
#
#          FLUXCAL  FLUXCALERR  PSF_SIG1  ...  SKY_SIG  SKY_SIG_T  RDNOISE  \
# 0     -45.258541   64.319351      1.46  ...     6.96        0.0     5.66
# 1      -2.313669   20.538248      1.19  ...     8.31        0.0     4.63
# 2     -32.685768   23.070316      1.03  ...     7.12        0.0     4.60
# 3      -3.364827   32.730373      0.95  ...     7.42        0.0    15.76
# 4    -159.439636  103.479820      1.10  ...     5.21        0.0     5.16
# ...          ...         ...       ...  ...      ...        ...      ...
# 8707  150.517548   36.076031      1.15  ...     7.30        0.0    12.99
# 8708    7.593536   70.141609      1.65  ...     8.43        0.0     4.48
# 8709  -27.734968   28.599686      1.47  ...     9.63        0.0     4.25
# 8710   45.825695   34.266922      1.51  ...     8.81        0.0     4.25
# 8711  188.376343   48.635082      1.49  ...     8.80        0.0    12.99
#
#          ZEROPT  ZEROPT_ERR  GAIN  XPIX  YPIX  SIM_FLUXCAL_HOSTERR  SIM_MAGOBS
# 0     27.320000       0.017  1.60  -9.0  -9.0                  0.0   32.009701
# 1     28.490000       0.008  3.86  -9.0  -9.0                  0.0   30.725010
# 2     28.219999       0.010  4.60  -9.0  -9.0                  0.0   31.053303
# 3     27.879999       0.009  6.57  -9.0  -9.0                  0.0   31.824049
# 4     26.190001       0.011  5.16  -9.0  -9.0                  0.0   32.636669
# ...         ...         ...   ...   ...   ...                  ...         ...
# 8707  27.860001       0.009  4.64  -9.0  -9.0                  0.0   21.963179
# 8708  27.520000       0.017  1.47  -9.0  -9.0                  0.0   26.691578
# 8709  28.379999       0.008  4.05  -9.0  -9.0                  0.0   23.939005
# 8710  28.200001       0.010  4.72  -9.0  -9.0                  0.0   22.640610
# 8711  27.850000       0.009  4.64  -9.0  -9.0                  0.0   22.078094
#
# [8712 rows x 22 columns]

# %%
print("# objects:", len(curves['obs'].value_counts()))

np.random.seed(45)

for i in np.random.randint(1, 100, 20):
    summary = table_summary[table_summary['CID']==i]
    plotter(curves, i, summary=summary)
# Out:
# # objects: 100

# %% [markdown]
# ### Problem:
#
# Which types there are? is not clear
